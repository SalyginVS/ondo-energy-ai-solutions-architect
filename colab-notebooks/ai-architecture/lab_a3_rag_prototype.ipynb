# %% [markdown]
# # Lab A3: RAG Prototype
# **Ondo Energy AI Solutions Architect Program**
#
# ## Setup
# Run on local machine pointing to Ollama API, or adapt for Google Colab with cloud LLM.

# %%
# Install dependencies
# !pip install chromadb langchain requests

OLLAMA_BASE_URL = 'http://127.0.0.1:11434'  # Local lab
EMBEDDING_MODEL = 'nomic-embed-text'          # Install via: ollama pull nomic-embed-text
LLM_MODEL = 'qwen3:14b'

print('Config loaded. Implement RAG pipeline here.')
